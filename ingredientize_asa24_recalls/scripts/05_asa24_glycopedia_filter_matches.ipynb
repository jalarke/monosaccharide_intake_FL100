# %%
import pandas as pd

# %%
# Load data
foods = pd.read_csv('data/asa24/asa24_ingredients/ingredient_frequency_nndc_120721.csv')

# %%
foods = foods[foods['glycan_match'] == 1]

# %%
foods
# Out:
#                                  Ingredient description  frequency  \
# 1                Alcoholic beverage, beer, regular, all        136
# 8                  Alcoholic beverage, wine, table, red        104
# 10                         Alfalfa seeds, sprouted, raw          6
# 12    Apple juice, canned or bottled, unsweetened, w...          4
# 13    Apple juice, canned or bottled, unsweetened, w...         10
# ...                                                 ...        ...
# 1193                                  Wild rice, cooked          5
# 1194                              Yambean (jicama), raw          3
# 1196                             Yogurt, plain, low fat        101
# 1197                           Yogurt, plain, skim milk         53
# 1198                          Yogurt, plain, whole milk         84
#
#       glycan_match              note
# 1                1               NaN
# 8                1               NaN
# 10               1               NaN
# ...

# %%
foods.to_csv('data/asa24/asa24_ingredients/ingredient_matches_120721.csv', index=None)
